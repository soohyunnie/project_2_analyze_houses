# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline

# %%
df =pd.read_csv('data/kc_house_data.csv')

# %%
df.loc[df['grade'] == 1, 'grade'] = 1
df.loc[df['grade'] == 2, 'grade'] = 1
df.loc[df['grade'] == 3, 'grade'] = 1
df.loc[df['grade'] == 4, 'grade'] = 2
df.loc[df['grade'] == 5, 'grade'] = 2
df.loc[df['grade'] == 6, 'grade'] = 2
df.loc[df['grade'] == 7, 'grade'] = 3
df.loc[df['grade'] == 8, 'grade'] = 3
df.loc[df['grade'] == 9, 'grade'] = 4
df.loc[df['grade'] == 10, 'grade'] = 4
df.loc[df['grade'] == 11, 'grade'] = 5
df.loc[df['grade'] == 12, 'grade'] = 5
df.loc[df['grade'] == 13, 'grade'] = 5

# %%
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0         NaN   0.0  ...      3        1180            0.0
# 1      7242     2.0         0.0   0.0  ...      3        2170          400.0
# 2     10000     1.0         0.0   0.0  ...      2         770            0.0
# 3      5000     1.0         0.0   0.0  ...      3        1050          910.0
# 4      8080     1.0         0.0   0.0  ...      3        1680            0.0
#
#   yr_built  yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21597 non-null  int64
#  1   date           21597 non-null  object
#  2   price          21597 non-null  float64
#  3   bedrooms       21597 non-null  int64
#  4   bathrooms      21597 non-null  float64
#  5   sqft_living    21597 non-null  int64
#  6   sqft_lot       21597 non-null  int64
#  7   floors         21597 non-null  float64
#  8   waterfront     19221 non-null  float64
#  9   view           21534 non-null  float64
#  10  condition      21597 non-null  int64
#  11  grade          21597 non-null  int64
#  12  sqft_above     21597 non-null  int64
#  13  sqft_basement  21597 non-null  object
#  14  yr_built       21597 non-null  int64
#  15  yr_renovated   17755 non-null  float64
#  16  zipcode        21597 non-null  int64
# ...

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.159700e+04  2.159700e+04  21597.000000  21597.000000  21597.000000
# mean   4.580474e+09  5.402966e+05      3.373200      2.115826   2080.321850
# std    2.876736e+09  3.673681e+05      0.926299      0.768984    918.106125
# min    1.000102e+06  7.800000e+04      1.000000      0.500000    370.000000
# 25%    2.123049e+09  3.220000e+05      3.000000      1.750000   1430.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.159700e+04  21597.000000  19221.000000  21534.000000  21597.000000
# mean   1.509941e+04      1.494096      0.007596      0.233863      3.409825
# ...

# %%
df.drop('id',inplace=True,axis=1)
df
# Out:
#              date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0      10/13/2014  221900.0         3       1.00         1180      5650
# 1       12/9/2014  538000.0         3       2.25         2570      7242
# 2       2/25/2015  180000.0         2       1.00          770     10000
# 3       12/9/2014  604000.0         4       3.00         1960      5000
# 4       2/18/2015  510000.0         3       2.00         1680      8080
# ...           ...       ...       ...        ...          ...       ...
# 21592   5/21/2014  360000.0         3       2.50         1530      1131
# 21593   2/23/2015  400000.0         4       2.50         2310      5813
# 21594   6/23/2014  402101.0         2       0.75         1020      1350
# 21595   1/16/2015  400000.0         3       2.50         1600      2388
# 21596  10/15/2014  325000.0         2       0.75         1020      1076
#
#        floors  waterfront  view  condition  grade  sqft_above sqft_basement  \
# ...

# %%
df['date'] = pd.to_datetime(df['date'])
df['year'] = df['date'].apply(lambda date: date.year)

# %%
df = df.drop('date', axis =1)

# %%
df['age'] = np.where(df['yr_renovated']>0, df['year'] - df['yr_renovated'], df['year']-df['yr_built'])

# %%
df =df.drop('year',axis =1)

# %%
df =df.drop('yr_built', axis =1)

# %%
df=df.drop('yr_renovated',axis =1)
df
# Out:
#           price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      221900.0         3       1.00         1180      5650     1.0
# 1      538000.0         3       2.25         2570      7242     2.0
# 2      180000.0         2       1.00          770     10000     1.0
# 3      604000.0         4       3.00         1960      5000     1.0
# 4      510000.0         3       2.00         1680      8080     1.0
# ...         ...       ...        ...          ...       ...     ...
# 21592  360000.0         3       2.50         1530      1131     3.0
# 21593  400000.0         4       2.50         2310      5813     2.0
# 21594  402101.0         2       0.75         1020      1350     2.0
# 21595  400000.0         3       2.50         1600      2388     2.0
# 21596  325000.0         2       0.75         1020      1076     2.0
#
#        waterfront  view  condition  grade  sqft_above sqft_basement  zipcode  \
# ...

# %%
x_var = df.columns[2:]
for x in x_var:
    df.plot(kind='scatter',x=x,y='price')

# %%
#Bedrooms has an outlier
#lots of'zeros' in yr_renovated

# %%
#taking out the bedroom outlier
df = df[df['bedrooms'] <15]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21596 entries, 0 to 21596
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   price          21596 non-null  float64
#  1   bedrooms       21596 non-null  int64
#  2   bathrooms      21596 non-null  float64
#  3   sqft_living    21596 non-null  int64
#  4   sqft_lot       21596 non-null  int64
#  5   floors         21596 non-null  float64
#  6   waterfront     19220 non-null  float64
#  7   view           21533 non-null  float64
#  8   condition      21596 non-null  int64
#  9   grade          21596 non-null  int64
#  10  sqft_above     21596 non-null  int64
#  11  sqft_basement  21596 non-null  object
#  12  zipcode        21596 non-null  int64
#  13  lat            21596 non-null  float64
#  14  long           21596 non-null  float64
#  15  sqft_living15  21596 non-null  int64
#  16  sqft_lot15     21596 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# price               0
# bedrooms            0
# bathrooms           0
# sqft_living         0
# sqft_lot            0
# floors              0
# waterfront       2376
# view               63
# condition           0
# grade               0
# sqft_above          0
# sqft_basement       0
# zipcode             0
# lat                 0
# long                0
# sqft_living15       0
# sqft_lot15          0
# age                 0
# dtype: int64

# %%
df['waterfront'].value_counts()
# Out:
# 0.0    19074
# 1.0      146
# Name: waterfront, dtype: int64

# %%
df['waterfront'].fillna(0, inplace =True)
# Out:
# /Users/avijames/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/series.py:4517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %%
df.isnull().sum()
# Out:
# price             0
# bedrooms          0
# bathrooms         0
# sqft_living       0
# sqft_lot          0
# floors            0
# waterfront        0
# view             63
# condition         0
# grade             0
# sqft_above        0
# sqft_basement     0
# zipcode           0
# lat               0
# long              0
# sqft_living15     0
# sqft_lot15        0
# age               0
# dtype: int64

# %%
df.dropna(inplace=True)
# Out:
# <ipython-input-364-c64f9f573c18>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace=True)

# %%
df = df[(df != '?').all(axis=1)]

# %%
df.isnull().sum()
# Out:
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# age              0
# dtype: int64

# %%
df['sqft_basement'] = df['sqft_basement'].astype(float)

# %%
df= df[df['sqft_lot']<300000]

# %%
from sklearn.model_selection import train_test_split
X = df.drop(['price'], axis=1)
y = df['price']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
fig, ax = plt.subplots(figsize=(20,10))
sns.heatmap(df.corr(), annot=True, )
# Out:
# <AxesSubplot:>

# %%
from sklearn.linear_model import LinearRegression

baseline_model = LinearRegression()

# %%
most_correlated_feature = 'sqft_living'

# %%
from sklearn.model_selection import cross_validate, ShuffleSplit

splitter = ShuffleSplit(n_splits=3, test_size=0.25, random_state=0)

baseline_scores = cross_validate(
    estimator=baseline_model,
    X=X_train[[most_correlated_feature]],
    y=y_train,
    return_train_score=True,
    cv=splitter
)

print("Train score:     ", baseline_scores["train_score"].mean())
print("Validation score:", baseline_scores["test_score"].mean())
# Out:
# Train score:      0.4907239933713791
# Validation score: 0.4912509005470221

# %%
scatterplot_data = X_train.drop("sqft_living", axis=1)

fig, axes = plt.subplots(ncols=3, nrows=6, figsize=(12, 8))
fig.set_tight_layout(True)

for index, col in enumerate(scatterplot_data.columns):
    ax = axes[index//3][index%3]
    ax.scatter(X_train[col], y_train, alpha=0.2)
    ax.set_xlabel(col)
    ax.set_ylabel("price")

# %%
X_train_second_model = X_train.drop(["sqft_lot15", "zipcode", "long", 'lat', 'waterfront','bedrooms','view', 'sqft_lot', 'floors', 'sqft_living15', 'sqft_above', 'bathrooms'], axis=1).copy()
X_test_second_model = X_test.drop(["sqft_lot15", "zipcode", "long", 'lat', 'waterfront', 'bedrooms', 'view','sqft_lot', 'floors', 'sqft_living15', 'sqft_above', 'bathrooms'], axis=1).copy()

# %%
second_model = LinearRegression()

second_model_scores = cross_validate(
    estimator=second_model,
    X=X_train_second_model,
    y=y_train,
    return_train_score=True,
    cv=splitter
)

print("Current Model")
print("Train score:     ", second_model_scores["train_score"].mean())
print("Validation score:", second_model_scores["test_score"].mean())
print()
print("Baseline Model")
print("Train score:     ", baseline_scores["train_score"].mean())
print("Validation score:", baseline_scores["test_score"].mean())
# Out:
# Current Model
# Train score:      0.5594048936591053
# Validation score: 0.5574258937450538
#
# Baseline Model
# Train score:      0.4999356811155328
# Validation score: 0.48899785840678334

# %%
#y_test
second_model = LinearRegression()

second_model_scores = cross_validate(
    estimator=second_model,
    X=X_test_second_model,
    y=y_test,
    return_train_score=True,
    cv=splitter
)

print("Current Model")
print("Train score:     ", second_model_scores["train_score"].mean())
print("Validation score:", second_model_scores["test_score"].mean())
print()
print("Baseline Model")
print("Train score:     ", baseline_scores["train_score"].mean())
print("Validation score:", baseline_scores["test_score"].mean())
# Out:
# Current Model
# Train score:      0.5710650887336935
# Validation score: 0.5668530750331348
#
# Baseline Model
# Train score:      0.4999356811155328
# Validation score: 0.48899785840678334

# %%
import statsmodels.api as sm

sm.OLS(y_train, sm.add_constant(X_train_second_model)).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.559
# Model:                            OLS   Adj. R-squared:                  0.559
# Method:                 Least Squares   F-statistic:                     3993.
# Date:                Wed, 25 Aug 2021   Prob (F-statistic):               0.00
# Time:                        11:51:50   Log-Likelihood:            -2.1788e+05
# No. Observations:               15759   AIC:                         4.358e+05
# Df Residuals:                   15753   BIC:                         4.358e+05
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
significant_features = ["bathrooms", "sqft_living", 'condition', 'age',]

# %%
X_train_second_model_dropped_grade= X_train_second_model.drop('grade', axis=1)
X_train_second_model_dropped_grade
# Out:
#        sqft_living  condition  sqft_basement    age
# 13216         1820          3          180.0   68.0
# 16883         4010          3            0.0   11.0
# 674           1800          3          600.0   46.0
# 21162         3030          3            0.0   10.0
# 12208         3020          3            0.0   12.0
# ...            ...        ...            ...    ...
# 11594         4170          4            0.0   24.0
# 12289         2290          3            0.0    7.0
# 5528          1660          3          700.0   73.0
# 884           3200          3         1040.0   62.0
# 16251         2550          4            0.0  109.0
#
# [15759 rows x 4 columns]

# %%
from sklearn.feature_selection import RFECV
from sklearn.preprocessing import StandardScaler

# Importances are based on coefficient magnitude, so
# we need to scale the data to normalize the coefficients
X_train_for_RFECV = StandardScaler().fit_transform(X_train_second_model_dropped_grade)

model_for_RFECV = LinearRegression()

# Instantiate and fit the selector
selector = RFECV(model_for_RFECV, cv=splitter)
selector.fit(X_train_for_RFECV, y_train)

# Print the results
print("Was the column selected?")
for index, col in enumerate(X_train_second_model_dropped_grade.columns):
    print(f"{col}: {selector.support_[index]}")
# Out:
# Was the column selected?
# sqft_living: True
# condition: False
# sqft_basement: False
# age: True

# %%
from itertools import combinations

features = ["bathrooms", "sqft_living", 'condition','age']

# Make a dataframe to hold the results (not strictly necessary
# but it makes the output easier to read)
results_df = pd.DataFrame(columns=features)

# Selecting just piece_count
results_df = results_df.append({
    "train_score": baseline_scores["train_score"].mean(),
    "val_score": baseline_scores["test_score"].mean()
}, ignore_index=True)

# Selecting 1 additional feature
for feature in features[1:]:
    scores = cross_validate(
        estimator=second_model,
        X=X_train[["sqft_living", feature]],
        y=y_train,
        return_train_score=True,
        cv=splitter
    )
    # Note: this technique of appending to a df is quite inefficient
    # Here it works because it's only happening 6 times, but avoid
    # doing this for a whole dataset
    results_df = results_df.append({
        feature: "Yes",
        "train_score": scores["train_score"].mean(),
        "val_score": scores["test_score"].mean()
    }, ignore_index=True)
    
# Selecting 2 additional features
for (feature1, feature2) in list(combinations(features[1:], 2)):
    scores = cross_validate(
        estimator=second_model,
        X=X_train[["sqft_living", feature1, feature2]],
        y=y_train,
        return_train_score=True,
        cv=splitter
    )
    results_df = results_df.append({
        feature1: "Yes",
        feature2: "Yes",
        "train_score": scores["train_score"].mean(),
        "val_score": scores["test_score"].mean()
    }, ignore_index=True)
    
# Including all 3 additional features
results_df = results_df.append({
    "train_score": second_model_scores["train_score"].mean(),
    "val_score": second_model_scores["test_score"].mean()
}, ignore_index=True)

# Fill in remaining values where appropriate
results_df["sqft_living"] = "Yes"
results_df.fillna("No", inplace=True)

results_df
# Out:
#   bathrooms sqft_living condition  age  train_score  val_score
# 0        No         Yes        No   No     0.499936   0.488998
# 1        No         Yes        No   No     0.490713   0.491150
# 2        No         Yes       Yes   No     0.496435   0.497464
# 3        No         Yes        No  Yes     0.513541   0.514756
# 4        No         Yes       Yes   No     0.496420   0.497383
# 5        No         Yes        No  Yes     0.513530   0.514639
# 6        No         Yes       Yes  Yes     0.513831   0.515100
# 7        No         Yes        No   No     0.571065   0.566853

# %%
sns.lmplot(data=df, x='price', y='sqft_living')
plt.xlabel('price')
plt.ylabel('sqft')
plt.title('sqft as a function of price');

# %%
from sklearn.preprocessing import OneHotEncoder

# Create OneHotEncoder object to create dummies by dropping the first category
ohe = OneHotEncoder(handle_unknown='ignore')

# Transform the dataset into dummies matrix
dummies = (X_train[['waterfront','view', 'condition']])
enc = ohe.fit(dummies)
trans = enc.transform(dummies)

dummies_test =(X_test[['waterfront', 'view', 'condition']])
trans_test = enc.transform(dummies_test)

# Dummies values in matrix form (without column names)
data = trans.todense()

# New dummy column names
names = ohe.get_feature_names(['waterfront', 'view', 'condition'] )

# Combine the values and column names into single dataframe
from sklearn.preprocessing import StandardScaler
data_scaler = X_train[['sqft_living', 'age','bathrooms', 'bedrooms',"sqft_lot15",'sqft_lot', 'floors', 'sqft_living15', 'sqft_above']]
scaler = StandardScaler()
df_fit = scaler.fit(data_scaler)
data_scaled = df_fit.transform(data_scaler)
scaled_df = pd.DataFrame(data_scaled, columns = ['sqft_living', 'age', 'bathrooms', 'bedrooms',"sqft_lot15",'sqft_lot', 'floors', 'sqft_living15', 'sqft_above'])



trans_df = pd.DataFrame(data, columns=names)
scaled_df.reset_index(drop=True, inplace=True)
trans_df.reset_index(drop=True, inplace=True)


X_train_comb = pd.concat([scaled_df, trans_df], axis=1)

# %%
data_test_scaler = X_test[['sqft_living', 'age','bathrooms', 'bedrooms',"sqft_lot15",'sqft_lot', 'floors', 'sqft_living15', 'sqft_above']]
data_test_scale = df_fit.transform(data_test_scaler)
test_scaled_df = pd.DataFrame(data_test_scale, columns = ['sqft_living', 'age', 'bathrooms', 'bedrooms',"sqft_lot15",'sqft_lot', 'floors', 'sqft_living15', 'sqft_above'])

data_test = trans_test.todense()
trans_test_df = pd.DataFrame(data_test, columns=names)

test_scaled_df.reset_index(drop=True, inplace=True)
trans_test_df.reset_index(drop=True, inplace=True)



X_test_comb = pd.concat([test_scaled_df, trans_test_df], axis=1)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm= LinearRegression()

# %%
lm.fit(X_train_comb, y_train)
# Out:
# LinearRegression()

# %%
print(lm.intercept_)
# Out:
# 903249.9660798954

# %%
coeff_df = pd.DataFrame(lm.coef_, X_train_comb.columns, columns=['Coefficient'])
coeff_df
# Out:
#                   Coefficient
# sqft_living     222342.151912
# age              78485.636509
# bathrooms        44940.137772
# bedrooms        -58650.570544
# sqft_lot15      -15496.570772
# sqft_lot         -7961.531602
# floors           24387.588297
# sqft_living15    41197.100355
# sqft_above       12308.249252
# waterfront_0.0 -252624.378034
# waterfront_1.0  252624.378034
# view_0.0       -146920.751073
# view_1.0         -9663.289948
# view_2.0        -70450.391828
# view_3.0          6178.428990
# view_4.0        220856.003859
# condition_1     -57973.197282
# condition_2     -29017.332129
# condition_3      11953.322908
# condition_4      20225.499196
# condition_5      54811.707307

# %%
from sklearn import metrics
import numpy as np

# %%
predictions = lm.predict(X_train_comb)

# %%
y_hat_train = lm.predict(X_train_comb)
y_hat_test = lm.predict(X_test_comb)

# %%
print('MAE:', metrics.mean_absolute_error(y_test, y_hat_test))
print('MSE:', metrics.mean_squared_error(y_test, y_hat_test))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, y_hat_test)))
# Out:
# MAE: 153640.16786256936
# MSE: 50581592011.963486
# RMSE: 224903.5171178154

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
print(f'Train R-Squared: {r2_score(y_train, y_hat_train)}')
print(f'Test R-Squared: {r2_score(y_test, y_hat_test)}\n')
# Out:
# Train R-Squared: 0.599341626590192
# Test R-Squared: 0.610611122620056

# %% [markdown]
# # Final Model

# %%
X = df[['sqft_living', 'bathrooms']]
y = df['price']

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print(lm.intercept_)
# Out:
# -8726714.251017334

# %%
coeff_df = pd.DataFrame(lm.coef_,X.columns,columns=['Coefficient'])
coeff_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/internals/managers.py in create_block_manager_from_blocks(blocks, axes)
#    1664
# -> 1665         mgr = BlockManager(blocks, axes)
#    1666         mgr._consolidate_inplace()
#
# ~/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/internals/managers.py in __init__(self, blocks, axes, do_integrity_check)
#     148         if do_integrity_check:
# --> 149             self._verify_integrity()
#     150
#
# ~/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/internals/managers.py in _verify_integrity(self)
#     325             if block.shape[1:] != mgr_shape[1:]:
# --> 326                 raise construction_error(tot_items, block.shape[1:], self.axes)
#     327         if len(self.items) != tot_items:
#
# ...

# %%
predictions = lm.predict(X_test)

# %%
plt.scatter(y_test,predictions)

# %%
sns.histplot((y_test-predictions),bins=50);

# %%
from sklearn import metrics

# %%
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 132777.62628537833
# MSE: 40317068208.472305
# RMSE: 200791.10589981894

# %%
sm.OLS(y_train, sm.add_constant(X_train)).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.680
# Model:                            OLS   Adj. R-squared:                  0.679
# Method:                 Least Squares   F-statistic:                     2086.
# Date:                Wed, 25 Aug 2021   Prob (F-statistic):               0.00
# Time:                        12:06:46   Log-Likelihood:            -2.1537e+05
# No. Observations:               15759   AIC:                         4.308e+05
# Df Residuals:                   15742   BIC:                         4.309e+05
# Df Model:                          16
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
from sklearn.model_selection import cross_validate, ShuffleSplit

splitter = ShuffleSplit(n_splits=3, test_size=0.25, random_state=0)

baseline_scores = cross_validate(
    estimator=baseline_model,
    X=X_train[['sqft_living', 'bathrooms']],
    y=y_train,
    return_train_score=True,
    cv=splitter
)

print("Train score:     ", baseline_scores["train_score"].mean())
print("Validation score:", baseline_scores["test_score"].mean())
# Out:
# Train score:      0.4907580523897823
# Validation score: 0.49131833830280874
